# %%
import sys

project_path = 'C:\\Users\\alexm\\Banking_ETL_Pyspark'

sys.path.append(project_path)

# %%
import random
from datetime import datetime
import pytest
from pyspark.sql import SparkSession, Row, DataFrame
from pyspark.sql.types import StructType, StructField, StringType, DateType, FloatType
from src.transformation.transform_account import AccountTransformer
from tests.configure_test import create_spark_session

# %%
account_transformer = AccountTransformer(spark)
# Out:
# ---------------------------------------------------------------------------
# Failed                                    Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 spark = create_spark_session()
#       3 account_transformer = AccountTransformer(spark)
#
# File c:\Users\alexm\anaconda3\envs\banking_env\lib\site-packages\_pytest\fixtures.py:1293, in FixtureFunctionDefinition.__call__(self, *args, **kwds)
#    1286 def __call__(self, *args: Any, **kwds: Any) -> Any:
#    1287     message = (
#    1288         f'Fixture "{self.name}" called directly. Fixtures are not meant to be called directly,\n'
#    1289         "but are created automatically when test functions request them as parameters.\n"
#    1290         "See https://docs.pytest.org/en/stable/explanation/fixtures.html for more information about fixtures, and\n"
#    1291         "https://docs.pytest.org/en/stable/deprecations.html#calling-fixtures-directly"
#    1292     )
# -> 1293     fail(message, pytrace=False)
#
# File c:\Users\alexm\anaconda3\envs\banking_env\lib\site-packages\_pytest\outcomes.py:177, in fail(reason, pytrace)
#     164 """Explicitly fail an executing test with the given message.
#     165
#     166 :param reason:
#    (...)
#     174     The exception that is raised.
#     175 """
#     176 __tracebackhide__ = True
# --> 177 raise Failed(msg=reason, pytrace=pytrace)
#
# Failed: Fixture "create_spark_session" called directly. Fixtures are not meant to be called directly,
# but are created automatically when test functions request them as parameters.
# See https://docs.pytest.org/en/stable/explanation/fixtures.html for more information about fixtures, and
# https://docs.pytest.org/en/stable/deprecations.html#calling-fixtures-directly
